# %%
import re
import os
with open("test.txt") as f:
    text = f.read()

re.findall("[^<a]+<a\\s+href=\"([^\"]+)",text)
# Out:
# ['https://audiobookbay.is',
#  'https://audiobookbay.is/member/login',
#  'https://audiobookbay.is/forum/general-requests/',
#  'https://audiobookbay.is/forum/',
#  'https://twitter.com/share',
#  'https://t.me/share/url?url=http://audiobookbay.is/page/1/?s=chicken+is&text= AudioBook Bay',
#  'https://wa.me/?text=http%3A%2F%2Faudiobookbay.is%2Fpage%2F1%2F%3Fs%3Dchicken%2Bis',
#  'javascript:document.searchform.submit();',
#  '/asbs/3126beastly-the-40000-year-story-of-animals-and-us-keggie-carew/',
#  '/member/users/index?&amp;mode=userinfo&amp;username=MojoYugen',
#  'https://audiobookbay.is/asbs/3126beastly-the-40000-year-story-of-animals-and-us-keggie-carew/',
#  '/asbs/5620the-last-ride-of-the-pony-express-my-2000-mile-horseback-journey-into-the-old-west-will-grant-2/',
#  '/member/users/index?&amp;mode=userinfo&amp;username=rmoor',
#  'https://audiobookbay.is/asbs/5620the-last-ride-of-the-pony-express-my-2000-mile-horseback-journey-into-the-old-west-will-grant-2/',
# ...
